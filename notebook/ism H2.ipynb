# %% [markdown]
# ## Step1: Imort Data

# %%
from ExtractSpec import *
import glob
import os 
from pathlib import Path
# Testing automatically find data file
from pathlib import Path
from ExtractSpec.paths import DATA_DIR, RESULTS_DIR, require, cd
#os.chdir('/media/kuo-jui/data/ISM_finalproject/backup_repo/2025Fall_ISM_Project')
#os.system('pip install -e .')

# Check the data directory is right
print("DATA:", DATA_DIR)
print("RESULTS:", RESULTS_DIR, '\n')

# Data Preparation
data_path = str(DATA_DIR)
os.chdir(data_path)
fitls = glob.glob('*.fits')
print(fitls)
data_dict = create_data_dict(fitls,check_header= True, check_file_header='TMC1A_g235h-f170lp_s3d.fits')
#print(data_dict.keys())
# 'TMC1A_g235h-f170lp_x1d', 'TMC1A_g140h-f100lp_x1d', 'TMC1A_g140h-f100lp_s3d', 'TMC1A_g395h-f290lp_x1d', 'TMC1A_g235h-f170lp_s3d', 'TMC1A_g395h-f290lp_s3d']
# wave init: 1.6601979666156694 um
# delta wave: 0.000395999988541007
# Out:
# DATA: /media/kuo-jui/data/ISM_finalproject/data
# RESULTS: /media/kuo-jui/data/ISM_finalproject/backup_repo/2025Fall_ISM_Project/results
#
# ['TMC1A_g235h-f170lp_x1d.fits', 'TMC1A_g140h-f100lp_x1d.fits', 'TMC1A_g140h-f100lp_s3d.fits', 'TMC1A_g395h-f290lp_x1d.fits', 'TMC1A_g235h-f170lp_s3d.fits', 'TMC1A_g395h-f290lp_s3d.fits']
# 7
# 7
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    3 / number of array dimensions
# NAXIS1  =                   53
# NAXIS2  =                   55
# NAXIS3  =                 3814
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# EXTNAME = 'SCI     '           / extension name
# SRCTYPE = 'EXTENDED'           / Source type used for calibration
# MJD-BEG =    59824.67665890046 / [d] exposure start time in MJD
# MJD-AVG =    59824.69107446951 / [d] exposure mid-point in MJD
# MJD-END =   59824.705490277775 / [d] exposure end time in MJD
# TDB-BEG =   59824.677213111885 / [d] TDB time of exposure start in MJD
# TDB-MID =    59824.69163011401 / [d] TDB time of exposure mid-point in MJD
# TDB-END =    59824.70604735535 / [d] TDB time of exposure end in MJD
# XPOSURE =   3865.2360000000003 / [s] Effective exposure time
# TELAPSE =    4122.924000000001 / [s] Total elapsed exposure time
#
#         JWST ephemeris information
#
# REFFRAME= 'EME2000 '           / Ephemeris reference frame (EME2000)
# EPH_TYPE= 'Definitive'         / Definitive or Predicted
# EPH_TIME=    59824.67864719329 / [d] MJD time of position and velocity vectors
# JWST_X  =    141345579.0025111 / [km] barycentric JWST X coordinate at MJD-AVG
# JWST_Y  =   -48528786.98895238 / [km] barycentric JWST Y coordinate at MJD-AVG
# JWST_Z  =  -20971897.078924447 / [km] barycentric JWST Z coordinate at MJD-AVG
# OBSGEO-X=    979353883.6479404 / [m] geocentric JWST X coordinate at MJD-AVG
# OBSGEO-Y=  -1034704124.0464722 / [m] geocentric JWST Y coordinate at MJD-AVG
# OBSGEO-Z=   -415693359.4502587 / [m] geocentric JWST Z coordinate at MJD-AVG
# JWST_DX =    9.938249913953747 / [km/s] barycentric JWST X velocity at MJD-AVG
# JWST_DY =   25.765116057934286 / [km/s] barycentric JWST Y velocity at MJD-AVG
# JWST_DZ =   11.350646714112079 / [km/s] barycentric JWST Z velocity at MJD-AVG
# OBSGEODX=   184.91831259926434 / [m/s] geocentric JWST X velocity at MJD-AVG
# OBSGEODY=   214.72694624051263 / [m/s] geocentric JWST Y velocity at MJD-AVG
# OBSGEODZ=    273.4441972399686 / [m/s] geocentric JWST Z velocity at MJD-AVG
# PA_APER =   41.216986010178736 / [deg] Position angle of aperture used
# VA_SCALE=   1.0000994148309266 / Velocity aberration scale factor
# BUNIT   = 'MJy/sr  '           / physical units of the array values
#
#         Photometry information
#
# PHOTMJSR=      3834411483136.0 / Flux density (MJy/steradian) producing 1 cps
# PHOTUJA2=     90125660848128.0 / Flux density (uJy/arcsec2) producing 1 cps
# PIXAR_SR= 2.35040007004737E-13 / Nominal pixel area in steradians
# PIXAR_A2= 0.010000000298023226 / Nominal pixel area in arcsec^2
#
#         Information about the coordinates in the file
#
# RADESYS = 'ICRS    '           / Name of the coordinate reference frame
#
#         Spacecraft pointing information
#
# RA_V1   =    69.75698558717372 / [deg] RA of telescope V1 axis
# DEC_V1  =   25.594389089653387 / [deg] Dec of telescope V1 axis
# PA_V3   =    262.1848451356005 / [deg] Position angle of telescope V3 axis
#
#         WCS parameters
#
# WCSAXES =                    3 / number of World Coordinate System axes
# CRPIX1  =                 27.0 / Axis 1 pixel coordinate of ref point, 1-indexed
# CRPIX2  =                 28.0 / Axis 2 pixel coordinate of ref point, 1-indexed
# CRPIX3  =                  1.0 / Axis 3 pixel coordinate of ref point, 1-indexed
# CRVAL1  =         69.896651741 / Axis 1 coordinate value at reference point
# CRVAL2  =         25.695624574 / Axis 2 coordinate value at reference point
# CRVAL3  =   1.6601979666156694 / Axis 3 coordinate value at reference point
# CTYPE1  = 'RA---TAN'           / Axis 1 type
# CTYPE2  = 'DEC--TAN'           / Axis 2 type
# CTYPE3  = 'WAVE    '           / Axis 3 type
# CUNIT1  = 'deg     '           / Axis 1 units
# CUNIT2  = 'deg     '           / Axis 2 units
# CUNIT3  = 'um      '           / Axis 3 units
# CDELT1  = 2.77777781916989E-05 / Axis 1 coordinate increment at reference point
# CDELT2  = 2.77777781916989E-05 / Axis 2 coordinate increment at reference point
# CDELT3  = 0.000395999988541007 / Axis 3 coordinate increment at reference point
# PC1_1   =                 -1.0 / Linear transformation matrix element
# PC1_2   =                  0.0 / Linear transformation matrix element
# PC1_3   =                    0 / Linear transformation matrix element
# PC2_1   =                  0.0 / Linear transformation matrix element
# PC2_2   =                  1.0 / Linear transformation matrix element
# PC2_3   =                    0 / Linear transformation matrix element
# PC3_1   =                    0 / Linear transformation matrix element
# PC3_2   =                    0 / Linear transformation matrix element
# PC3_3   =                    1 / Linear transformation matrix element
# S_REGION= 'POLYGON ICRS  69.895850255 25.694874572 69.895850255 25.696374572 &'
# CONTINUE  '69.897453227 25.696374572 69.897453227 25.694874572&'
# CONTINUE  '' / spatial extent of the observation, footprint
# WAVSTART=             1.66E-06 / Lower bound of the default wavelength range
# WAVEND  =             3.17E-06 / Upper bound of the default wavelength range
# DISPAXIS=                    1 / Dispersion direction
# SPORDER =                   -1 / Spectral order number
# VELOSYS =            -29802.31 / [m/s] Barycentric correction to radial velocity
# SPECSYS = 'BARYCENT'           / Spectral reference frame
# EXTVER  =                    1 / extension value
# 3
# 3
# 3
# 3
# 7
# 7
# 3
# 3
# 7
# 7
# 7
# 7
# data_dict keys: dict_keys(['TMC1A_g235h-f170lp_x1d', 'TMC1A_g140h-f100lp_x1d', 'TMC1A_g140h-f100lp_s3d', 'TMC1A_g395h-f290lp_x1d', 'TMC1A_g235h-f170lp_s3d', 'TMC1A_g395h-f290lp_s3d'])

# %% [markdown]
# ## Step2: Overview the image and spectrum

# %%
# Plot the raw image, g140 
import matplotlib.pyplot as plt
import matplotlib as mpl


data = data_dict['TMC1A_g235h-f170lp_s3d']['data']
header = data_dict['TMC1A_g235h-f170lp_s3d']['header']
# pixel = data_dict['TMC1A_g140h.s3d']['header']['CDELT1']*3600 # change the pixel unit  qfrom deg to arcsec

plot_image(data[1165], header, vmin = -1, vmax = 1e3, a = 1e-2, text = '-30km/s', add_patch = (35,42), savefig = False, save_name = 'g235_H2_1165.png')
plot_image(data[1166], header, vmin = -1, vmax = 1e3, a = 1e-2, text = '30km/s', add_patch = (35,42), savefig = False, save_name = 'g235_H2_1166.png')

# H2 emissions: one of it is at 1165 and 1166
# Out:
# plotting single cross (tuple)
# plotting single cross (tuple)

# %%
# Calculate the flux and wavelength of each channel
wave, flux = calc_spec(data, header = header)
# Out:
# Sr in pixel: 2.3504431239584476e-13
# Begin to calculate spectrum flux without continuum subtraction...
# Calculating spectrum flux: 100%|██████████| 3814/3814 [00:31<00:00, 120.17it/s]
# Finish calculate spectrum flux without continuum subtraction!!
# Return the wave and flux arrays.

# %%
#%matplotlib tk
plot_line_spectrum(wave, header, flux, xlim = (-400,400), ylim = (0.0375, 0.05), 
                   text = ('2.122', r'$H_2$'), restwave = 2.122, exclude=[(2.4138,2.469)],
                   savefig = False, save_name = 'H2_2.122_spectrum.png', plot_all_spec= True)
# 2.415~2.468

# %% [markdown]
# ## Step3: Continuum subtraction using Sagov-filter
# The method is based on JDISC program and ctool (https://github.com/pontoppi/ctool). After that we will correct the radial velocity.

# %% [markdown]
# ### Explanation of Continuum Subtraction Process
# The `calc_cont` function implements a robust method for continuum subtraction using median filtering and anchor points. Here's how it works:
#
# 1. **Median Filter**:
#    - Uses `medfilt` with a specified box size (default=101)
#    - Smooths the data by replacing each point with the median of its surrounding points
#    - Helps remove noise while preserving sharp spectral features
#
# 2. **Anchor Points Selection**:
#    - Identifies reliable continuum points using a threshold (default=0.998)
#    - Points where smoothed flux > original flux × threshold become anchor points
#    - If too few anchors found (< 2), relaxes threshold to 0.99
#    - If still insufficient, falls back to using smoothed data
#
# 3. **Continuum Estimation**:
#    - Uses linear interpolation between anchor points
#    - Preserves the actual continuum shape without being affected by emission/absorption lines
#    - Iterative process refines the estimate over multiple passes
#
# 4. **Final Smoothing**:
#    - Applies Savitzky-Golay filter for final smoothing
#    - Window size = 3 × boxsize
#    - Uses first-order polynomial fit
#
# This method is particularly effective because:
# - Median filtering preserves sharp features
# - Anchor points ensure we're using reliable continuum regions
# - Interpolation helps avoid contamination from spectral lines
# - Multiple iterations help refine the final result
#
# This work is totally based on the ctool package.

# %%
# From previous result we can see that there are lots of bad pixel, so we first need to use shift coordinat and continuum subtraction
# Reminder: g140_s3d is the original data cube
import bettermoments as bm
from tqdm.notebook import tqdm

cont_one_spaxel, line_one_spaxel = generate_line_cont(data[:, 42:43, 35:36], wave, boxsize= 13 )

cont_spaxel, line_spaxel = generate_line_cont(data, wave, boxsize= 31, exclude=[(2.4138,2.469)])
# Out:
# Generating continuum and line emission cubes: 100%|██████████| 1/1 [00:00<00:00, 333.36it/s]
# Generating continuum and line emission cubes: 100%|██████████| 55/55 [00:07<00:00,  7.17it/s]

# %%
# Plot the continuum emission of the FeII 1.644
# The reddshift side might locate at 190 km/s index = 2871
plot_image(line_spaxel[1165], header, vmin = -1, vmax = 1e3, a = 1e-3, text = '-30km/s', add_patch = (35,42), savefig = False, save_name = 'line_1165.png')
plot_image(line_spaxel[1166], header, vmin = -1, vmax = 1e3, a = 1e-3, text = '30km/s', add_patch = (35,42), savefig = False, save_name = 'line_1166.png')
plot_image(cont_spaxel[1165], header, vmin = -1, vmax = 1e3, a = 1e-2, text = '30km/s', add_patch = (35,42), savefig = False, save_name = 'cont_2866.png')
# Out:
# plotting single cross (tuple)
# plotting single cross (tuple)
# plotting single cross (tuple)

# %%
# Plot the spectrum with conntinuum subtraction, g140
cont, flux_line = calc_contsubtract_spec(line_one_spaxel, cont_one_spaxel, header = header)
print(flux_line)
# Out:
# Sr in pixel: 2.3504431239584476e-13
# Calculating spectrum flux with continuum subtraction: 100%|██████████| 3814/3814 [00:00<00:00, 51614.96it/s]
# [4.82927144e-06 4.09556492e-06 2.79629850e-06 ... 3.71762627e-06
#  4.89997105e-06 0.00000000e+00]

# %%
#%matplotlib tk
v_2122 = optical_veocity(wave, header, restwave = 2.122)
# Plot the comparison between line and continuum emissions
plot_comparison_line_continuum(v_2122, wave, flux, flux_line, cont, 
                               xlim = (800, -800), ylim = (5e-5, 0),
                               plot_all_spec = False, savefig = False, save_name = 'Comparison_line_cont.png')

# %% [markdown]
# ### Note
# For Fe II boxsize =13 is enoug but for larger wavelegnth we need to use other size of box size.

# %%
# Save the line data and continuum data in new fits file
import os
import astropy.io.fits as fits
# Create directory to save the new fits files

#if not os.path.exists('subtract_continuum'):
#    os.mkdir('subtract_continuum')
os.chdir(data_path + '/subtract_continuum/g235h')
# export continuum as *_cont.fits
hdu_new = fits.PrimaryHDU(data = cont_spaxel, header = header)
hdu_new.writeto('TMC1A_g235h-f170lp_s3d'+'_cont.fits', overwrite=True)
# export continuum as *_line.fits
hdu_new = fits.PrimaryHDU(data = line_spaxel, header = header)
hdu_new.writeto('TMC1A_g235h-f170lp_s3d'+'_line.fits', overwrite=True)

# %% [markdown]
# ## Step 4: Create Moment zero and one map by using bettermoments

# %%
# Generate Moment zero and one map of H2 1.622 the line emission
#filepath = '/media/kuo-jui/data/ISM_finalproject/subtract_continuum/'
#os.chdir(filepath)


cont_data, cont_wave = bm.load_cube('TMC1A_g235h-f170lp_s3d_line.fits')

# Decide the moment map region [w1:w2]

rms = bm.estimate_RMS(data=cont_data[1151:1183, 24:30, 35:44 ], N=10) # set it in a line free region
print('RMS = {:.1f} mJy/beam (original)'.format(rms ))

w1, w2 = 1151, 1183
cont_data = cont_data[w1:w2]
cont_wave = cont_wave[w1:w2]
cont_vel = optical_veocity(cont_wave, header = header , restwave = 2.122)

user_mask = bm.get_user_mask(data= cont_data, user_mask_path=None)

threshold_mask = bm.get_threshold_mask(data= cont_data,
                                       clip= 5,
                                       smooth_threshold_mask=0.0)

channel_mask = bm.get_channel_mask(data = cont_data,
                                   firstchannel = 0,
                                   lastchannel = -1)

mask = bm.get_combined_mask(user_mask = user_mask, threshold_mask = threshold_mask, channel_mask = channel_mask, combine = 'and')
masked_data = cont_data *mask

moments = bm.collapse_zeroth(velax= cont_vel, data= masked_data, rms= rms)
bm.save_to_FITS(moments = moments, method= 'zeroth', path= 'TMC1A_g235h-f170lp_s3d_line.fits', outname = 'TMC1A_g235h-f170lp_s3d_line.5sigclip.fits')

moments = bm.collapse_first(velax= cont_vel, data= masked_data, rms= rms)
bm.save_to_FITS(moments = moments, method= 'first', path= 'TMC1A_g235h-f170lp_s3d_line.fits', outname = 'TMC1A_g235h-f170lp_s3d_line.5sigclip.fits')
# Out:
# RMS = 1.1 mJy/beam (original)

# %%
# Read the continuum moment 0 map
#ilepath = '/media/kuo-jui/data/ISM_finalproject/subtract_continuum/'
os.chdir(data_path + '/subtract_continuum/g235h')

import os
import astropy.io.fits as fits
#os.chdir('subtract_continuum')
fitls = glob.glob('*.fits')
subcont_dict = {}
for i in fitls:
    hdul = fits.open(i)
    header = hdul[0].header
    data = hdul[0].data
    name = i.split('.fits')[0]
    subcont_dict['%s' %(name)] = {'header': header, 'data': data}
print(subcont_dict.keys())
# 'TMC1A_g235h-f170lp_s3d_line.5sigclip_dM1', 'TMC1A_g235h-f170lp_s3d_line', 'TMC1A_g235h-f170lp_s3d_line.5sigclip_M1', 
# 'TMC1A_g235h-f170lp_s3d_cont', 'TMC1A_g235h-f170lp_s3d_line.5sigclip_dM0', 'TMC1A_g235h-f170lp_s3d_line.5sigclip_M0'
# Out:
# dict_keys(['TMC1A_g235h-f170lp_s3d_line.5sigclip_dM1', 'TMC1A_g235h-f170lp_s3d_line', 'TMC1A_g235h-f170lp_s3d_line.5sigclip_M1', 'TMC1A_g235h-f170lp_s3d_cont', 'TMC1A_g235h-f170lp_s3d_line.5sigclip_dM0', 'TMC1A_g235h-f170lp_s3d_line.5sigclip_M0'])

# %%
# Plot the Moment zero map of 1.644 line
g235_s3d_line_M0 = subcont_dict['TMC1A_g235h-f170lp_s3d_line.5sigclip_M0']['data']
pixel = subcont_dict['TMC1A_g235h-f170lp_s3d_line.5sigclip_M0']['header']['CDELT1']*3600 # change the pixel unit  qfrom deg to arcsec

plot_image(data = g235_s3d_line_M0, header = header, vmin = -1, vmax = 1e5)
'''
def axis_transfer(pos,val):
    return f'{pos*pixel:.2f}'

fig = plt.figure(figsize = (8,10))

widths = [0.05,1]
heights = [0.05,1]
gs = fig.add_gridspec(2, 2, width_ratios=widths,height_ratios=heights)
gs.update(left=0.05, right=0.95, bottom=0.08, top=0.85, wspace=0.02, hspace=0.02)

ax1 = fig.add_subplot(gs[1,1])
cbar1 = fig.add_subplot(gs[0,1])
norm1 = ImageNormalize(g140_s3d_lint_M0, vmin= -1, vmax = 1e5, stretch=AsinhStretch(a=1e-2))
plt1 = ax1.imshow(g140_s3d_lint_M0, norm = norm1, cmap= 'inferno', origin = 'lower')
cb1 = Colorbar(ax = cbar1, mappable = plt1, orientation = 'horizontal', ticklocation = 'top', ticks = [0, 1e3, 1e4, 5e4, 1e5])

ax1.xaxis.set_major_formatter(FuncFormatter(axis_transfer))
ax1.yaxis.set_major_formatter(FuncFormatter(axis_transfer))
ax1.set_xlabel(r'$\Delta \alpha$' +' [arcsec]', fontsize = 15)
ax1.set_ylabel(r'$\Delta \delta$'+' [arcsec]',fontsize = 15)
ax1.text(0.05,0.95, 'FeII',transform=ax1.transAxes,fontsize = 15)
cbar1.set_title('MJy/Sr km/s',fontsize = 25, pad= 10)
'''
# Out:
# No valid patch input, skipping...
# "\ndef axis_transfer(pos,val):\n    return f'{pos*pixel:.2f}'\n\nfig = plt.figure(figsize = (8,10))\n\nwidths = [0.05,1]\nheights = [0.05,1]\ngs = fig.add_gridspec(2, 2, width_ratios=widths,height_ratios=heights)\ngs.update(left=0.05, right=0.95, bottom=0.08, top=0.85, wspace=0.02, hspace=0.02)\n\nax1 = fig.add_subplot(gs[1,1])\ncbar1 = fig.add_subplot(gs[0,1])\nnorm1 = ImageNormalize(g140_s3d_lint_M0, vmin= -1, vmax = 1e5, stretch=AsinhStretch(a=1e-2))\nplt1 = ax1.imshow(g140_s3d_lint_M0, norm = norm1, cmap= 'inferno', origin = 'lower')\ncb1 = Colorbar(ax = cbar1, mappable = plt1, orientation = 'horizontal', ticklocation = 'top', ticks = [0, 1e3, 1e4, 5e4, 1e5])\n\nax1.xaxis.set_major_formatter(FuncFormatter(axis_transfer))\nax1.yaxis.set_major_formatter(FuncFormatter(axis_transfer))\nax1.set_xlabel(r'$\\Delta \x07lpha$' +' [arcsec]', fontsize = 15)\nax1.set_ylabel(r'$\\Delta \\delta$'+' [arcsec]',fontsize = 15)\nax1.text(0.05,0.95, 'FeII',transform=ax1.transAxes,fontsize = 15)\ncbar1.set_title('MJy/Sr km/s',fontsize = 25, pad= 10)\n"

# %%
# Plot the Moment one map of 1.644 line
g235_s3d_line_M1 = subcont_dict['TMC1A_g235h-f170lp_s3d_line.4sigclip_M1']['data']
pixel = subcont_dict['TMC1A_g235h-f170lp_s3d_line.4sigclip_M1']['header']['CDELT1']*3600 # change the pixel unit  qfrom deg to arcsec

'''
def axis_transfer(pos,val):
    return f'{pos*pixel:.2f}'

fig = plt.figure(figsize = (8,10))

widths = [0.05,1]
heights = [0.05,1]
gs = fig.add_gridspec(2, 2, width_ratios=widths,height_ratios=heights)
gs.update(left=0.05, right=0.95, bottom=0.08, top=0.85, wspace=0.02, hspace=0.02)

ax1 = fig.add_subplot(gs[1,1])
cbar1 = fig.add_subplot(gs[0,1])
norm1 = ImageNormalize(g140_s3d_line_M1, vmin= -200, vmax = 200)
plt1 = ax1.imshow(g140_s3d_line_M1, norm = norm1, cmap= 'RdBu_r', origin = 'lower')
cb1 = Colorbar(ax = cbar1, mappable = plt1, orientation = 'horizontal', ticklocation = 'top')

ax1.xaxis.set_major_formatter(FuncFormatter(axis_transfer))
ax1.yaxis.set_major_formatter(FuncFormatter(axis_transfer))
ax1.set_xlabel(r'$\Delta \alpha$' +' [arcsec]', fontsize = 15)
ax1.set_ylabel(r'$\Delta \delta$'+' [arcsec]',fontsize = 15)
ax1.text(0.05,0.95, r'$1.644\mu m$',transform=ax1.transAxes,fontsize = 15)
cbar1.set_title('km/s',fontsize = 25, pad= 10)
'''
# Out:
# "\ndef axis_transfer(pos,val):\n    return f'{pos*pixel:.2f}'\n\nfig = plt.figure(figsize = (8,10))\n\nwidths = [0.05,1]\nheights = [0.05,1]\ngs = fig.add_gridspec(2, 2, width_ratios=widths,height_ratios=heights)\ngs.update(left=0.05, right=0.95, bottom=0.08, top=0.85, wspace=0.02, hspace=0.02)\n\nax1 = fig.add_subplot(gs[1,1])\ncbar1 = fig.add_subplot(gs[0,1])\nnorm1 = ImageNormalize(g140_s3d_line_M1, vmin= -200, vmax = 200)\nplt1 = ax1.imshow(g140_s3d_line_M1, norm = norm1, cmap= 'RdBu_r', origin = 'lower')\ncb1 = Colorbar(ax = cbar1, mappable = plt1, orientation = 'horizontal', ticklocation = 'top')\n\nax1.xaxis.set_major_formatter(FuncFormatter(axis_transfer))\nax1.yaxis.set_major_formatter(FuncFormatter(axis_transfer))\nax1.set_xlabel(r'$\\Delta \x07lpha$' +' [arcsec]', fontsize = 15)\nax1.set_ylabel(r'$\\Delta \\delta$'+' [arcsec]',fontsize = 15)\nax1.text(0.05,0.95, r'$1.644\\mu m$',transform=ax1.transAxes,fontsize = 15)\ncbar1.set_title('km/s',fontsize = 25, pad= 10)\n"

# %%
# Generate Moment zero map of FeII 1.644 the continuum emission
os.chdir(data_path + 'subtract_continuum')


cont_data, cont_wave = bm.load_cube('TMC1A_g140h.s3d_cont.fits')

# Decide the moment map region [w1:w2]

rms = bm.estimate_RMS(data=cont_data[2840:2885, 10:15, 24:34 ], N=10) # set it in a line free region
print('RMS = {:.1f} mJy/beam (original)'.format(rms ))

w1, w2 = 2860, 2870
cont_data = cont_data[w1:w2]
cont_wave = cont_wave[w1:w2]
cont_vel = optical_veocity(cont_wave, w1644_rest)

user_mask = bm.get_user_mask(data= cont_data, user_mask_path=None)

threshold_mask = bm.get_threshold_mask(data= cont_data,
                                       clip= None,
                                       smooth_threshold_mask=0.0)

channel_mask = bm.get_channel_mask(data = cont_data,
                                   firstchannel = 0,
                                   lastchannel = -1)

mask = bm.get_combined_mask(user_mask = user_mask, threshold_mask = threshold_mask, channel_mask = channel_mask, combine = 'and')
masked_data = cont_data *mask

moments = bm.collapse_zeroth(velax= cont_vel, data= masked_data, rms= rms)
bm.save_to_FITS(moments = moments, method= 'zeroth', path= filepath+"TMC1A_g140h.s3d_line.fits")

#moments = bm.collapse_first(velax= cont_vel, data= masked_data, rms= rms)
#bm.save_to_FITS(moments = moments, method= 'first', path= filepath+"TMC1A_g140h.s3d_line.fits")

# Read the continuum moment 0 map
filepath = '/media/kuo-jui/data/ISM_finalproject/subtract_continuum/'
os.chdir(filepath)

fitls = glob.glob('*.fits')
subcont_dict = {}
for i in fitls:
    hdul = fits.open(i)
    header = hdul[0].header
    data = hdul[0].data
    name = i.split('.')[0] +'.' + i.split('.')[1]
    subcont_dict['%s' %(name)] = {'header': header, 'data': data}
print(subcont_dict.keys())
# dict_keys(['TMC1A_g140h.s3d_line', 'TMC1A_g140h.s3d_cont_dM0', 'TMC1A_g140h.s3d_cont_M0', 'TMC1A_g140h.s3d_cont'])
# Out:
# RMS = 0.2 mJy/beam (original)
# dict_keys(['TMC1A_g140h.s3d_line_M0', 'TMC1A_g140h.s3d_line', 'TMC1A_g140h.s3d_line_dM0', 'TMC1A_g140h.s3d_line_M1', 'TMC1A_g140h.s3d_cont_dM0', 'TMC1A_g140h.s3d_cont_M0', 'TMC1A_g140h.s3d_cont', 'TMC1A_g140h.s3d_line_dM1'])

# %%
# Plot the raw image, g140 
g140_s3d_cont_M0 = subcont_dict['TMC1A_g140h.s3d_cont_M0']['data']
pixel = subcont_dict['TMC1A_g140h.s3d_cont_M0']['header']['CDELT1']*3600 # change the pixel unit  qfrom deg to arcsec

def axis_transfer(pos,val):
    return f'{pos*pixel:.2f}'

fig = plt.figure(figsize = (8,10))

widths = [0.05,1]
heights = [0.05,1]
gs = fig.add_gridspec(2, 2, width_ratios=widths,height_ratios=heights)
gs.update(left=0.05, right=0.95, bottom=0.08, top=0.85, wspace=0.02, hspace=0.02)

ax1 = fig.add_subplot(gs[1,1])
cbar1 = fig.add_subplot(gs[0,1])
norm1 = ImageNormalize(g140_s3d_cont_M0, vmin= -1, vmax = 5e5, stretch=AsinhStretch(a=5e-3))
plt1 = ax1.imshow(g140_s3d_cont_M0, norm = norm1, cmap= 'inferno', origin = 'lower')
cb1 = Colorbar(ax = cbar1, mappable = plt1, orientation = 'horizontal', ticklocation = 'top', ticks = [0, 1e3, 1e4, 5e4, 5e5])

ax1.xaxis.set_major_formatter(FuncFormatter(axis_transfer))
ax1.yaxis.set_major_formatter(FuncFormatter(axis_transfer))
ax1.set_xlabel(r'$\Delta \alpha$' +' [arcsec]', fontsize = 15)
ax1.set_ylabel(r'$\Delta \delta$'+' [arcsec]',fontsize = 15)
ax1.text(0.05,0.95, 'FeII',transform=ax1.transAxes,fontsize = 15)
cbar1.set_title('MJy/Sr km/s',fontsize = 25, pad= 10)
# Out:
# Text(0.5, 1.0, 'MJy/Sr km/s')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
